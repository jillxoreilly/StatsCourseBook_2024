# %% [markdown]
# # Exam Resit 2024 q2 - Model Answers
#
# **A research team in Australia wanted to investigate how long people stay in their jobs and collected data from the social networking site LinkedIn. The data file linkedin.csv contains the following variables:**
#
# * Jobdays (continuous, number of days person has been in their current role)
# * Age (continuous)
# * Agecat (Age recoded into 3 categories – youngest, mid, oldest)
# * Gender (3 categories - male, female, other or missing)
# * Companysize (continuous, number of staff)
# * Companysizecat (4 categories - small, medium, large, very large)
# * Followers on Linkedin (continuous, number of followers)

# %%
# Set-up Python libraries - you need to run this but you don't need to change it
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import seaborn as sns
sns.set_theme(style='white')
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# **a) Load the data as a pandas dataframe and call it linkedin.**

# %%
linkedin = pd.read_csv('Linkedin.csv')
linkedin
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 linkedin = pd.read_csv('Linkedin.csv')
#       2 linkedin
#
# File /opt/anaconda3/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
